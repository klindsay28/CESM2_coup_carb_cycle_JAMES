# %%
import xarray as xr
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fname = '/glade/campaign/collections/cmip/CMIP6/timeseries-cmip6/b.e21.B1850.f19_g17.CMIP6-piControl-2deg.001/ocn/proc/tseries/month_1/b.e21.B1850.f19_g17.CMIP6-piControl-2deg.001.pop.h.SSH.000101-005012.nc'
ds = xr.open_dataset(fname)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                 (d2: 2, lat_aux_grid: 395, moc_comp: 3, moc_z: 61, nlat: 384, nlon: 320, time: 600, transport_comp: 5, transport_reg: 2, z_t: 60, z_t_150m: 15, z_w: 60, z_w_bot: 60, z_w_top: 60)
# Coordinates:
#   * z_t                     (z_t) float32 500.0 1500.0 ... 512502.8 537500.0
#   * z_t_150m                (z_t_150m) float32 500.0 1500.0 ... 13500.0 14500.0
#   * z_w                     (z_w) float32 0.0 1000.0 ... 500004.7 525000.94
#   * z_w_top                 (z_w_top) float32 0.0 1000.0 ... 500004.7 525000.94
#   * z_w_bot                 (z_w_bot) float32 1000.0 2000.0 ... 549999.06
#   * lat_aux_grid            (lat_aux_grid) float32 -79.48815 -78.952896 ... 90.0
#   * moc_z                   (moc_z) float32 0.0 1000.0 ... 525000.94 549999.06
#     ULONG                   (nlat, nlon) float64 ...
#     ULAT                    (nlat, nlon) float64 ...
#     TLONG                   (nlat, nlon) float64 ...
# ...

# %%
KMT = ds['KMT'].fillna(0)
KMT = ds['KMT']
KMT.plot()
plt.show()
(KMT > 0).plot()
plt.show()

# %%
xr.where(KMT > 0, 1.0, 0.0).plot()

# %%
xr.where((KMT > 0) & (ds['TLAT'] < -30.0), 1.0, 0.0).plot()

# %%
xr.where((KMT > 0) & (ds['TLAT'] < -44.0), 1.0, 0.0).plot()

# %%
xr.where((KMT > 0) & (ds['TLAT'] >= -44.0) & (ds['TLAT'] < -18.0), 1.0, 0.0).plot()

# %%
xr.where((KMT > 0) & (ds['TLAT'] >= -18.0) & (ds['TLAT'] < 18.0), 1.0, 0.0).plot()

# %%
xr.where((KMT > 0) & (ds['TLAT'] >= 18.0) & (ds['TLAT'] < 49.0), 1.0, 0.0).plot()

# %%
xr.where((KMT > 0) & (ds['TLAT'] >= 49.0), 1.0, 0.0).plot()
