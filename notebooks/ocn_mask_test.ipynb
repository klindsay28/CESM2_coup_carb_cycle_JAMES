# %%
import xarray as xr
import matplotlib.pyplot as plt
from src.utils_grid import get_rmask
# %matplotlib inline

# %% [markdown]
# # use a single variable timeseries file with land-block elimination

# %%
fname = '/glade/campaign/collections/cmip/CMIP6/timeseries-cmip6/b.e21.B1850.f19_g17.CMIP6-piControl-2deg.001/ocn/proc/tseries/month_1/b.e21.B1850.f19_g17.CMIP6-piControl-2deg.001.pop.h.SSH.000101-005012.nc'
ds = xr.open_dataset(fname)

rmask = get_rmask(ds, "ocn")

print(rmask["region"])
# Out:
# 2020-02-12 16:28:53.537556(get_rmask):rmask_od created
# <xarray.DataArray 'region' (region: 18)>
# array(['Global', 'SouOce (90S-30S)', 'SH_high_lat (90S-44S)',
#        'SH_high_lat_ATL (90S-44S)', 'SH_high_lat_IND (90S-44S)',
#        'SH_high_lat_PAC (90S-44S)', 'SH_mid_lat_ATL (44S-18S)',
#        'SH_mid_lat_IND (44S-18S)', 'SH_mid_lat_PAC (44S-18S)',
#        'low_lat_ATL (18S-18N)', 'low_lat_IND (18S-27N)',
#        'low_lat_PAC (18S-18N)', 'NH_mid_lat_ATL (18N-45N)',
#        'NH_mid_lat_PAC (18N-45N)', 'NH_subpolar_ATL (45N-90N)',
#        'NH_high_lat_PAC (45N-90N)', 'GIN', 'ARC'], dtype='<U25')
# Coordinates:
#   * region   (region) <U25 'Global' 'SouOce (90S-30S)' ... 'GIN' 'ARC'

# %% [markdown]
# # show regions

# %%
for region_ind in range(rmask.sizes["region"]):
    rmask.isel(region=region_ind).plot()
    plt.show()
